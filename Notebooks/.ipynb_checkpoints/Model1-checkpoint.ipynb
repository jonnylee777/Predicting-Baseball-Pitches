# %%
from sklearn.model_selection import train_test_split, GroupKFold, cross_val_score
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, ConfusionMatrixDisplay
from sklearn.dummy import DummyClassifier
from sklearn.ensemble import RandomForestClassifier, HistGradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC
from sklearn.base import clone
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
#Read in kg1_cleaned from the cleaned notebook
kg1 = pd.read_csv("../data/kg1_cleaned.csv")

# %% [markdown]
# ## Shared Modeling Setup
#
# This section defines the shared modeling workflow used throughout the notebook.
#
# Key rules:
# - The train/test split is created **once** at the game level using `game_pk`.
# - `des`, `game_pk`, and `game_date` are dropped consistently for every KG model.
# - Tree models use numeric `-999` imputation and categorical `"Missing"` + one-hot encoding.
# - Linear models use the same logic, plus numeric scaling.
# - Group CV is run with the preprocessing inside the CV pipeline to avoid leakage across folds.

# %%
from sklearn.model_selection import train_test_split, GroupKFold, cross_val_score
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, ConfusionMatrixDisplay
from sklearn.dummy import DummyClassifier
from sklearn.ensemble import RandomForestClassifier, HistGradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC
from sklearn.base import clone
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Columns that should not be used as model features.
# game_pk is used for splitting/grouping, not prediction.
# game_date can create time leakage / unstable behavior.
# des is a text description of the pitch/play and can leak outcome information.
BASE_DROP_COLS = ["game_pk", "game_date", "des"]
TARGET_COL = "pitch_type"

# %%
def make_preprocessor(X_train_raw, model_family="tree"):
    """
    Build a consistent preprocessing object from the training data.

    model_family="tree":
        numeric -> impute missing values as -999
        categorical -> impute as "Missing", then one-hot encode

    model_family="linear":
        same as tree, but also scales numeric variables after imputation
        useful for Logistic Regression and Linear SVM
    """
    numeric_cols = X_train_raw.select_dtypes(include=["number"]).columns.tolist()
    categorical_cols = X_train_raw.select_dtypes(include=["object", "category", "bool"]).columns.tolist()

    numeric_steps = [("imputer", SimpleImputer(strategy="constant", fill_value=-999))]

    if model_family == "linear":
        numeric_steps.append(("scaler", StandardScaler()))
    elif model_family != "tree":
        raise ValueError("model_family must be either 'tree' or 'linear'")

    numeric_transformer = Pipeline(steps=numeric_steps)

    categorical_transformer = Pipeline(steps=[
        ("imputer", SimpleImputer(strategy="constant", fill_value="Missing")),
        ("onehot", make_onehot_encoder())
    ])

    return ColumnTransformer(
        transformers=[
            ("num", numeric_transformer, numeric_cols),
            ("cat", categorical_transformer, categorical_cols)
        ],
        remainder="drop"
    )

# %%
def split_raw_data_by_games(df, train_games, target_col=TARGET_COL, drop_cols=BASE_DROP_COLS):
    """
    Apply the one shared game-level split to a KG dataset and return raw X/y.
    The raw X objects are used to fit either tree or linear preprocessors.
    """
    train_mask = df["game_pk"].isin(train_games)

    train_df = df.loc[train_mask].copy()
    test_df = df.loc[~train_mask].copy()

    y_train = train_df[target_col]
    y_test = test_df[target_col]

    cols_to_drop = [target_col] + list(drop_cols)
    X_train_raw = train_df.drop(columns=cols_to_drop, errors="ignore")
    X_test_raw = test_df.drop(columns=cols_to_drop, errors="ignore")

    groups = train_df["game_pk"]

    return {
        "train_df": train_df,
        "test_df": test_df,
        "X_train_raw": X_train_raw,
        "X_test_raw": X_test_raw,
        "y_train": y_train,
        "y_test": y_test,
        "groups": groups
    }

# %%
def prepare_model_data(df, train_games, model_family="tree", target_col=TARGET_COL, drop_cols=BASE_DROP_COLS):
    """
    Split a KG dataset using the shared train_games, then fit/transform preprocessing.
    This is called once per KG/model family.
    """
    data = split_raw_data_by_games(df, train_games, target_col=target_col, drop_cols=drop_cols)

    preprocessor = make_preprocessor(data["X_train_raw"], model_family=model_family)
    X_train = preprocessor.fit_transform(data["X_train_raw"])
    X_test = preprocessor.transform(data["X_test_raw"])

    data["X_train"] = X_train
    data["X_test"] = X_test
    data["preprocessor"] = preprocessor
    data["feature_names"] = preprocessor.get_feature_names_out()
    data["model_family"] = model_family

    return data

# %%
def make_cv_pipeline(model, X_train_raw, model_family):
    """
    Build a fresh pipeline for grouped CV.
    Preprocessing is fit separately inside each CV fold.
    """
    return Pipeline(steps=[
        ("preprocessor", make_preprocessor(X_train_raw, model_family=model_family)),
        ("classifier", clone(model))
    ])

# %%
def evaluate_prepared_model(model, data, model_name, kg_name, model_family, results_df, show_confusion_matrix=True):
    """
    Fit a model on already-prepared train/test matrices, print evaluation output,
    run grouped CV correctly with preprocessing inside each fold, append results,
    and display the updated comparison table.
    """
    model.fit(data["X_train"], data["y_train"])

    y_pred_train = model.predict(data["X_train"])
    y_pred_test = model.predict(data["X_test"])

    train_accuracy = accuracy_score(data["y_train"], y_pred_train)
    test_accuracy = accuracy_score(data["y_test"], y_pred_test)

    print(f"{kg_name} {model_name} Training Accuracy: {train_accuracy:.4f}")
    print(f"{kg_name} {model_name} Testing Accuracy : {test_accuracy:.4f}")
    print("\nClassification Report")
    print(classification_report(data["y_test"], y_pred_test, zero_division=0))

    if show_confusion_matrix:
        cm = confusion_matrix(data["y_test"], y_pred_test, labels=model.classes_)
        disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=model.classes_)
        fig, ax = plt.subplots(figsize=(8, 8))
        disp.plot(ax=ax, cmap="Blues", xticks_rotation=45)
        plt.title(f"{kg_name} {model_name} Confusion Matrix")
        plt.tight_layout()
        plt.show()

    cv = GroupKFold(n_splits=5)
    cv_pipeline = make_cv_pipeline(model, data["X_train_raw"], model_family=model_family)

    cv_scores = cross_val_score(
        cv_pipeline,
        data["X_train_raw"],
        data["y_train"],
        cv=cv,
        groups=data["groups"],
        scoring="accuracy",
        n_jobs=-1
    )

    cv_mean = cv_scores.mean()

    print(f"{kg_name} {model_name} Group CV Scores:", cv_scores)
    print(f"{kg_name} {model_name} Mean Group CV Accuracy: {cv_mean:.4f}")
    print(f"{kg_name} {model_name} Group CV Std: {cv_scores.std():.4f}")

    new_row = pd.DataFrame([{
        "KG Dataset": kg_name,
        "Model": model_name,
        "Preprocessing": model_family,
        "Train Accuracy": train_accuracy,
        "Test Accuracy": test_accuracy,
        "Group CV Accuracy": cv_mean
    }])

    results_df = pd.concat([results_df, new_row], ignore_index=True)

    display(
        results_df.assign(
            **{
                "Train Accuracy": results_df["Train Accuracy"].round(4),
                "Test Accuracy": results_df["Test Accuracy"].round(4),
                "Group CV Accuracy": results_df["Group CV Accuracy"].round(4)
            }
        )
    )

    return model, y_pred_test, results_df

# %%
def evaluate_naive_stratified(data, kg_name, results_df):
    """Evaluate the stratified dummy baseline using the same train/test games and grouped CV."""
    naive_model = DummyClassifier(strategy="stratified", random_state=42)

    naive_model.fit(data["X_train_raw"], data["y_train"])
    y_pred_train = naive_model.predict(data["X_train_raw"])
    y_pred_test = naive_model.predict(data["X_test_raw"])

    train_accuracy = accuracy_score(data["y_train"], y_pred_train)
    test_accuracy = accuracy_score(data["y_test"], y_pred_test)

    print(f"{kg_name} Naive Stratified Training Accuracy: {train_accuracy:.4f}")
    print(f"{kg_name} Naive Stratified Testing Accuracy : {test_accuracy:.4f}")

    cv = GroupKFold(n_splits=5)
    cv_scores = cross_val_score(
        DummyClassifier(strategy="stratified", random_state=42),
        data["X_train_raw"],
        data["y_train"],
        cv=cv,
        groups=data["groups"],
        scoring="accuracy",
        n_jobs=-1
    )
    cv_mean = cv_scores.mean()

    print(f"{kg_name} Naive Stratified Group CV Scores:", cv_scores)
    print(f"{kg_name} Naive Stratified Mean Group CV Accuracy: {cv_mean:.4f}")

    new_row = pd.DataFrame([{
        "KG Dataset": kg_name,
        "Model": "Naive Stratified",
        "Preprocessing": "none",
        "Train Accuracy": train_accuracy,
        "Test Accuracy": test_accuracy,
        "Group CV Accuracy": cv_mean
    }])

    results_df = pd.concat([results_df, new_row], ignore_index=True)

    display(
        results_df.assign(
            **{
                "Train Accuracy": results_df["Train Accuracy"].round(4),
                "Test Accuracy": results_df["Test Accuracy"].round(4),
                "Group CV Accuracy": results_df["Group CV Accuracy"].round(4)
            }
        )
    )

    return naive_model, y_pred_test, results_df

# %%
def feature_importance_table(model, feature_names, top_n=25):
    """Create a feature-importance table for tree-based models with feature_importances_."""
    importance_df = (
        pd.DataFrame({
            "Feature": feature_names,
            "Importance": model.feature_importances_
        })
        .sort_values("Importance", ascending=False)
        .reset_index(drop=True)
    )
    return importance_df.head(top_n)

# %%
def rounded_results(results_df):
    """Pretty display version of the model comparison table."""
    return results_df.assign(
        **{
            "Train Accuracy": results_df["Train Accuracy"].round(4),
            "Test Accuracy": results_df["Test Accuracy"].round(4),
            "Group CV Accuracy": results_df["Group CV Accuracy"].round(4)
        }
    )


# One shared game-level train/test split for every KG iteration.
all_games = kg1["game_pk"].dropna().unique()

train_games, test_games = train_test_split(
    all_games,
    test_size=0.20,
    random_state=42
)

print(f"Train games: {len(train_games)}")
print(f"Test games : {len(test_games)}")

# Main comparison table. This gets updated after every model run.
model_results = pd.DataFrame(columns=[
    "KG Dataset",
    "Model",
    "Preprocessing",
    "Train Accuracy",
    "Test Accuracy",
    "Group CV Accuracy"
])
# Out:
# Train games: 222
# Test games : 56

# %%
def make_onehot_encoder():
    """Create a dense one-hot encoder that works across sklearn versions."""
    try:
        return OneHotEncoder(handle_unknown="ignore", sparse_output=False)
    except TypeError:
        return OneHotEncoder(handle_unknown="ignore", sparse=False)

# %% [markdown]
# ## KG1 Model
#
# KG1 is the cleaned base dataset after leakage-safe previous-pitch and previous-at-bat transformations.
#
# For Random Forest, KG1 uses the shared tree preprocessing pipeline:
# - drop `game_pk`, `game_date`, and `des`
# - numeric missing values → `-999`
# - categorical missing values → `"Missing"`
# - one-hot encode categoricals

# %%
# Prepare KG1 once for tree-based models
kg1_tree_data = prepare_model_data(kg1, train_games, model_family="tree")

print("KG1 raw train shape:", kg1_tree_data["X_train_raw"].shape)
print("KG1 processed train shape:", kg1_tree_data["X_train"].shape)
print("KG1 raw test shape:", kg1_tree_data["X_test_raw"].shape)
print("KG1 processed test shape:", kg1_tree_data["X_test"].shape)
# Out:
# KG1 raw train shape: (19949, 114)
# KG1 processed train shape: (19949, 217)
# KG1 raw test shape: (4891, 114)
# KG1 processed test shape: (4891, 217)

# %% [markdown]
# ### KG1 Naive Stratified Baseline

# %%
kg1_naive_model, kg1_naive_pred, model_results = evaluate_naive_stratified(
    data=kg1_tree_data,
    kg_name="KG1",
    results_df=model_results
)
# Out:
# KG1 Naive Stratified Training Accuracy: 0.4270
# KG1 Naive Stratified Testing Accuracy : 0.4265
# KG1 Naive Stratified Group CV Scores: [0.41198596 0.42614346 0.43674699 0.44249562 0.43663739]
# KG1 Naive Stratified Mean Group CV Accuracy: 0.4308
# /var/folders/xl/0mdbqj151h998r8m4wkx2x1c0000gn/T/ipykernel_98906/387854640.py:39: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, new_row], ignore_index=True)
#   KG Dataset             Model Preprocessing  Train Accuracy  Test Accuracy  \
# 0        KG1  Naive Stratified          none           0.427         0.4265
#
#    Group CV Accuracy
# 0             0.4308

# %% [markdown]
# ### KG1 Random Forest

# %%
kg1_rf = RandomForestClassifier(
    n_estimators=500,
    max_depth=12,
    min_samples_leaf=5,
    min_samples_split=10,
    max_features="sqrt",
    random_state=42,
    n_jobs=-1
)

kg1_rf, kg1_rf_pred, model_results = evaluate_prepared_model(
    model=kg1_rf,
    data=kg1_tree_data,
    model_name="Random Forest",
    kg_name="KG1",
    model_family="tree",
    results_df=model_results
)
# Out:
# KG1 Random Forest Training Accuracy: 1.0000
# KG1 Random Forest Testing Accuracy : 0.5915
#
# Classification Report
#               precision    recall  f1-score   support
#
#           CH       0.00      0.00      0.00        74
#           FF       0.59      0.88      0.71      2636
#           FS       0.59      0.34      0.43      1672
#           SL       0.50      0.01      0.01       504
#           ST       0.00      0.00      0.00         5
#
#     accuracy                           0.59      4891
#    macro avg       0.34      0.25      0.23      4891
# weighted avg       0.57      0.59      0.53      4891
# KG1 Random Forest Group CV Scores: [0.57998997 0.5996001  0.61470884 0.59834628 0.59949812]
# KG1 Random Forest Mean Group CV Accuracy: 0.5984
# KG1 Random Forest Group CV Std: 0.0110
#   KG Dataset             Model Preprocessing  Train Accuracy  Test Accuracy  \
# 0        KG1  Naive Stratified          none           0.427         0.4265
# 1        KG1     Random Forest          tree           1.000         0.5915
#
#    Group CV Accuracy
# 0             0.4308
# 1             0.5984

# %% [markdown]
# ## KG2 Edits
#
# KG2 starts from KG1, then removes lower-level/redundant variables and adds more interpretable baseball context features.

# %%
kg2 = kg1.copy()

# %%
#remove intentional walk rows
kg2 = kg2.dropna(subset=["pitch_type"]).copy()

# %% [markdown]
# ### Rename variables for clarity

# %%
kg2.rename(columns={'pitch_number': 'pitch_number_of_ab', "at_bat_number": "at_bat_number_of_game"}, inplace=True)

# %% [markdown]
# ### Drop variables
# Here, we drop the redundant pitch characterstic variables

# %%
# =========================
# Create kg2: Interpretable Front-Office Model Dataset
# =========================
remove_from_kg2 = [
    # Low-level trajectory variables
    "vx0_of_prev_pitch",
    "vy0_of_prev_pitch",
    "vz0_of_prev_pitch",
    "ax_of_prev_pitch",
    "ay_of_prev_pitch",
    "az_of_prev_pitch",
    "plate_z_of_prev_pitch",
    "plate_x_of_prev_pitch",
    "pfx_z_of_prev_pitch",
    "pfx_x_of_prev_pitch",

    # API / derived break variables
    "api_break_z_with_gravity_of_prev_pitch",
    "api_break_x_arm_of_prev_pitch",
    "api_break_x_batter_in_of_prev_pitch",

    # Hawkeye / swing-mechanics variables
    "attack_angle_of_prev_pitch",
    "hyper_speed_of_prev_pitch",
    "attack_direction_of_prev_pitch",
    "swing_length_of_prev_pitch",
    "intercept_ball_minus_batter_pos_x_inches_of_prev_pitch",
    "intercept_ball_minus_batter_pos_y_inches_of_prev_pitch",
    "swing_path_tilt_of_prev_pitch",

    # Dense release / spin / location variables removed for kg2
    "arm_angle_of_prev_pitch",
    "release_spin_rate_of_prev_pitch",
    "spin_axis_of_prev_pitch",
    "release_extension_of_prev_pitch",
    "release_pos_x_of_prev_pitch",
    "release_pos_y_of_prev_pitch",
    "release_pos_z_of_prev_pitch",

    # IDs / deprecated / non-useful fields
    "sv_id",
    "game_year",
    "tfs_deprecated",
    "tfs_zulu_deprecated",
    "spin_dir",
    "spin_rate_deprecated",
    "break_angle_deprecated",
    "break_length_deprecated",
    "des"
]

kg2 = kg2.drop(columns=remove_from_kg2, errors="ignore")

print("kg1 shape:", kg1.shape)
print("kg2 shape:", kg2.shape)
print("Columns removed:", kg1.shape[1] - kg2.shape[1])
# Out:
# kg1 shape: (24840, 118)
# kg2 shape: (24840, 82)
# Columns removed: 36

# %% [markdown]
# ### Previous pitch type

# %%
# Create previous pitch type (within each game)

kg2["pitch_type_of_prev_pitch"] = (
    kg2.sort_values(["game_pk", "at_bat_number_of_game", "pitch_number_of_ab"])
       .groupby("game_pk")["pitch_type"]
       .shift(1)
)

# %%
kg2.head()
# Out:
#     game_date  pitch_number_of_ab  at_bat_number_of_game events_of_prev_ab  \
# 0  2017-04-28                   3                      0               NaN
# 1  2017-04-28                   4                      0               NaN
# 2  2017-04-28                   5                      0               NaN
# 3  2017-04-28                   6                      0               NaN
# 4  2017-04-28                   1                      1              walk
#
#    hit_location_of_prev_ab bb_type_of_prev_ab  \
# 0                      NaN                NaN
# 1                      NaN                NaN
# 2                      NaN                NaN
# 3                      NaN                NaN
# 4                      NaN                NaN
#
#    estimated_ba_using_speedangle_of_prev_ab  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#    estimated_woba_using_speedangle_of_prev_ab  woba_value_of_prev_ab  \
# 0                                         NaN                    NaN
# 1                                         NaN                    NaN
# 2                                         NaN                    NaN
# 3                                         NaN                    NaN
# 4                                    0.692994                    0.7
#
#    woba_denom_of_prev_ab  ...  delta_home_win_exp_of_prev_pitch  \
# 0                    NaN  ...                               NaN
# 1                    NaN  ...                             0.005
# 2                    NaN  ...                             0.010
# 3                    NaN  ...                            -0.009
# 4                    1.0  ...                             0.030
#
#    delta_run_exp_of_prev_pitch  bat_speed_of_prev_pitch  \
# 0                          NaN                      NaN
# 1                        0.056                      NaN
# 2                        0.131                      NaN
# 3                       -0.089                      NaN
# 4                        0.349                      NaN
#
#    miss_distance_of_prev_pitch  estimated_slg_using_speedangle_of_prev_pitch  \
# 0                          NaN                                           NaN
# 1                          NaN                                           NaN
# 2                          NaN                                           NaN
# 3                          NaN                                           NaN
# 4                          NaN                                           NaN
#
#   delta_pitcher_run_exp_of_prev_pitch hit_distance_sc_of_prev_pitch  \
# 0                                 NaN                           NaN
# 1                              -0.056                           NaN
# 2                              -0.131                           NaN
# 3                               0.089                           NaN
# 4                              -0.349                           NaN
#
#    launch_speed_of_prev_pitch  launch_angle_of_prev_pitch  \
# 0                         NaN                         NaN
# 1                         NaN                         NaN
# 2                         NaN                         NaN
# 3                         NaN                         NaN
# 4                         NaN                         NaN
#
#   pitch_type_of_prev_pitch
# 0                      NaN
# 1                       FF
# 2                       FS
# 3                       FF
# 4                       FF
#
# [5 rows x 83 columns]

# %% [markdown]
# ### Pitcher/Hitter Handedness

# %%
# Create binary feature: 1 if pitcher and batter have the same handedness, 0 otherwise
kg2["p/h_hand"] = (kg2["p_throws"] == kg2["stand"]).astype(int)

# %% [markdown]
# ### Count leverage indicator

# %%
# Create exact count feature
kg2["count"] = (
    kg2["balls"].astype(int).astype(str)
    + "-"
    + kg2["strikes"].astype(int).astype(str)
)

# %%
def classify_count(row):
    balls = row["balls"]
    strikes = row["strikes"]

    if balls == 3 and strikes == 2:
        return "full_count"
    elif strikes == 2 and balls < 3:
        return "put_away_count"
    elif balls >= 2 and strikes <= 1:
        return "hitters_count"
    elif strikes > balls:
        return "pitcher_ahead"
    elif balls > strikes:
        return "pitcher_behind"
    else:
        return "even_count"

kg2["count_state"] = kg2.apply(classify_count, axis=1)

# %% [markdown]
# ### Pitch number of game

# %%
# Pitch number within the game (1, 2, 3, ...)
kg2["pitch_number_of_game"] = (
    kg2.groupby("game_pk").cumcount() + 1
)

# %% [markdown]
# ### Number of career matchups

# %%
# Sort chronologically across seasons
kg2 = kg2.sort_values(
    ["game_date", "game_pk", "at_bat_number_of_game", "pitch_number_of_ab"]
).reset_index(drop=True)

# One row per plate appearance / at-bat
pa_level = (
    kg2[["game_date", "game_pk", "at_bat_number_of_game", "pitcher", "batter"]]
    .drop_duplicates(subset=["game_pk", "at_bat_number_of_game"])
    .sort_values(["game_date", "game_pk", "at_bat_number_of_game"])
    .copy()
)

# Previous career PAs this batter has had against this pitcher
pa_level["prior_pa_vs_pitcher_career"] = (
    pa_level
    .groupby(["pitcher", "batter"])
    .cumcount()
)

# Merge back onto every pitch
kg2 = kg2.merge(
    pa_level[["game_pk", "at_bat_number_of_game", "prior_pa_vs_pitcher_career"]],
    on=["game_pk", "at_bat_number_of_game"],
    how="left"
)

# %% [markdown]
# ### Pitcher team lead

# %%
kg2["pitcher_team_score_diff"] = kg2["fld_score"] - kg2["bat_score"]

# %% [markdown]
# ### Strike Zone Height

# %%
kg2['strike_zone_height'] = kg2.sz_top - kg2.sz_bot

# %% [markdown]
# ## KG2 Model
#
# KG2 uses the same shared split and the same Random Forest preprocessing logic as KG1.

# %%
# Prepare KG2 once for tree-based models
kg2_tree_data = prepare_model_data(kg2, train_games, model_family="tree")

print("KG2 raw train shape:", kg2_tree_data["X_train_raw"].shape)
print("KG2 processed train shape:", kg2_tree_data["X_train"].shape)
print("KG2 raw test shape:", kg2_tree_data["X_test_raw"].shape)
print("KG2 processed test shape:", kg2_tree_data["X_test"].shape)
# Out:
# KG2 raw train shape: (19949, 87)
# KG2 processed train shape: (19949, 211)
# KG2 raw test shape: (4891, 87)
# KG2 processed test shape: (4891, 211)

# %% [markdown]
# ### KG2 Random Forest

# %%
kg2_rf = RandomForestClassifier(
    n_estimators=500,
    max_depth=12,
    min_samples_leaf=5,
    min_samples_split=10,
    max_features="sqrt",
    random_state=42,
    n_jobs=-1
)

kg2_rf, kg2_rf_pred, model_results = evaluate_prepared_model(
    model=kg2_rf,
    data=kg2_tree_data,
    model_name="Random Forest",
    kg_name="KG2",
    model_family="tree",
    results_df=model_results
)
# Out:
# KG2 Random Forest Training Accuracy: 1.0000
# KG2 Random Forest Testing Accuracy : 0.5956
#
# Classification Report
#               precision    recall  f1-score   support
#
#           CH       0.00      0.00      0.00        74
#           FF       0.60      0.86      0.70      2636
#           FS       0.59      0.39      0.47      1672
#           SL       0.22      0.00      0.01       504
#           ST       0.00      0.00      0.00         5
#
#     accuracy                           0.60      4891
#    macro avg       0.28      0.25      0.24      4891
# weighted avg       0.55      0.60      0.54      4891
# KG2 Random Forest Group CV Scores: [0.58525577 0.60459885 0.62123494 0.60035079 0.60025094]
# KG2 Random Forest Mean Group CV Accuracy: 0.6023
# KG2 Random Forest Group CV Std: 0.0115
#   KG Dataset             Model Preprocessing  Train Accuracy  Test Accuracy  \
# 0        KG1  Naive Stratified          none           0.427         0.4265
# 1        KG1     Random Forest          tree           1.000         0.5915
# 2        KG2     Random Forest          tree           1.000         0.5956
#
#    Group CV Accuracy
# 0             0.4308
# 1             0.5984
# 2             0.6023

# %% [markdown]
# ## KG3 Edits
#
# KG3 starts from KG2, removes additional features, and adds rolling previous-pitch-mix features.

# %%
# -------------------------
# Create kg3
# -------------------------

kg3 = kg2.copy()

kg3_drop_cols = [
    "effective_speed_of_prev_pitch",
    "delta_home_win_exp_of_prev_pitch",
    "home_win_exp",
    "age_bat_legacy",
    "post_home_score",
    "fielder_2",
    "fielder_3",
    "fielder_4",
    "fielder_5",
    "fielder_6",
    "fielder_7",
    "fielder_8",
    "fielder_9",
    "home_score",
    "away_score",
    "home_score_diff",
    "age_pit_legacy",
    "pitcher_days_until_next_game",
    "batter_days_until_next_game",
    "player_name",
    "batter_days_since_prev_game",
    "p/h_hand"
    
]

kg3 = kg3.drop(columns=kg3_drop_cols)

kg3.shape
# Out:
# (24840, 68)

# %% [markdown]
# ### 3-pitch mix rolling average

# %%
# -------------------------
# KG3 rolling pitch mix: previous 3 pitches
# Uses pitch_type, then shifts backward so current pitch is excluded
# -------------------------

kg3 = kg3.sort_values(
    ["game_date", "game_pk", "at_bat_number_of_game", "pitch_number_of_ab"]
).reset_index(drop=True)

pitch_dummies_3 = pd.get_dummies(
    kg3["pitch_type"],
    prefix="prev3_pitch_rate"
)

# Shift within pitcher so each row only sees pitches BEFORE the current pitch
pitch_dummies_3_shifted = (
    pitch_dummies_3
    .groupby(kg3["pitcher"])
    .shift(1)
)

rolling_3 = (
    pitch_dummies_3_shifted
    .groupby(kg3["pitcher"])
    .rolling(window=3, min_periods=1)
    .mean()
    .reset_index(level=0, drop=True)
)

kg3 = pd.concat([kg3, rolling_3], axis=1)

# %%
kg3.head(20)
# Out:
#      game_date  pitch_number_of_ab  at_bat_number_of_game  \
# 0   2017-04-28                   3                      0
# 1   2017-04-28                   4                      0
# 2   2017-04-28                   5                      0
# 3   2017-04-28                   6                      0
# 4   2017-04-28                   1                      1
# 5   2017-04-28                   2                      1
# 6   2017-04-28                   1                      2
# 7   2017-04-28                   2                      2
# 8   2017-04-28                   3                      2
# 9   2017-04-28                   4                      2
# 10  2017-04-28                   5                      2
# 11  2017-04-28                   6                      2
# 12  2017-04-28                   1                      3
# 13  2017-04-28                   2                      3
# 14  2017-04-28                   3                      3
# 15  2017-04-28                   4                      3
# 16  2017-04-28                   1                      4
# 17  2017-04-28                   2                      4
# 18  2017-04-28                   3                      4
# 19  2017-04-28                   4                      4
#
#             events_of_prev_ab  hit_location_of_prev_ab bb_type_of_prev_ab  \
# 0                         NaN                      NaN                NaN
# 1                         NaN                      NaN                NaN
# 2                         NaN                      NaN                NaN
# 3                         NaN                      NaN                NaN
# 4                        walk                      NaN                NaN
# 5                        walk                      NaN                NaN
# 6   grounded_into_double_play                      6.0        ground_ball
# 7   grounded_into_double_play                      6.0        ground_ball
# 8   grounded_into_double_play                      6.0        ground_ball
# 9   grounded_into_double_play                      6.0        ground_ball
# 10  grounded_into_double_play                      6.0        ground_ball
# 11  grounded_into_double_play                      6.0        ground_ball
# 12                     single                      8.0         line_drive
# 13                     single                      8.0         line_drive
# 14                     single                      8.0         line_drive
# 15                     single                      8.0         line_drive
# 16                  field_out                      7.0           fly_ball
# 17                  field_out                      7.0           fly_ball
# 18                  field_out                      7.0           fly_ball
# 19                  field_out                      7.0           fly_ball
#
#     estimated_ba_using_speedangle_of_prev_ab  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# 5                                        NaN
# 6                                      0.085
# 7                                      0.085
# 8                                      0.085
# 9                                      0.085
# 10                                     0.085
# 11                                     0.085
# 12                                     0.633
# 13                                     0.633
# 14                                     0.633
# 15                                     0.633
# 16                                     0.100
# 17                                     0.100
# 18                                     0.100
# 19                                     0.100
#
#     estimated_woba_using_speedangle_of_prev_ab  woba_value_of_prev_ab  \
# 0                                          NaN                    NaN
# 1                                          NaN                    NaN
# 2                                          NaN                    NaN
# 3                                          NaN                    NaN
# 4                                     0.692994                    0.7
# 5                                     0.692994                    0.7
# 6                                     0.077000                    0.0
# 7                                     0.077000                    0.0
# 8                                     0.077000                    0.0
# 9                                     0.077000                    0.0
# 10                                    0.077000                    0.0
# 11                                    0.077000                    0.0
# 12                                    0.584000                    0.9
# 13                                    0.584000                    0.9
# 14                                    0.584000                    0.9
# 15                                    0.584000                    0.9
# 16                                    0.161000                    0.0
# 17                                    0.161000                    0.0
# 18                                    0.161000                    0.0
# 19                                    0.161000                    0.0
#
#     woba_denom_of_prev_ab  ...     count_state  pitch_number_of_game  \
# 0                     NaN  ...      even_count                     1
# 1                     NaN  ...   hitters_count                     2
# 2                     NaN  ...   hitters_count                     3
# 3                     NaN  ...      full_count                     4
# 4                     1.0  ...      even_count                     5
# 5                     1.0  ...  pitcher_behind                     6
# 6                     1.0  ...      even_count                     7
# 7                     1.0  ...   pitcher_ahead                     8
# 8                     1.0  ...  put_away_count                     9
# 9                     1.0  ...  put_away_count                    10
# 10                    1.0  ...  put_away_count                    11
# 11                    1.0  ...  put_away_count                    12
# 12                    1.0  ...      even_count                    13
# 13                    1.0  ...  pitcher_behind                    14
# 14                    1.0  ...      even_count                    15
# 15                    1.0  ...  put_away_count                    16
# 16                    1.0  ...      even_count                    17
# 17                    1.0  ...  pitcher_behind                    18
# 18                    1.0  ...   hitters_count                    19
# 19                    1.0  ...   hitters_count                    20
#
#     prior_pa_vs_pitcher_career  pitcher_team_score_diff  strike_zone_height  \
# 0                            0                        4            1.688094
# 1                            0                        4            1.736089
# 2                            0                        4            1.704043
# 3                            0                        4            1.927603
# 4                            0                        4            2.027311
# 5                            0                        4            2.219007
# 6                            0                        4            1.779910
# 7                            0                        4            2.179052
# 8                            0                        4            1.620136
# 9                            0                        4            1.700017
# 10                           0                        4            2.179052
# 11                           0                        4            2.179052
# 12                           0                        4            1.612328
# 13                           0                        4            1.724121
# 14                           0                        4            2.250971
# 15                           0                        4            2.250971
# 16                           0                        8            1.959472
# 17                           0                        8            1.863637
# 18                           0                        8            2.039337
# 19                           0                        8            2.007391
#
#    prev3_pitch_rate_CH  prev3_pitch_rate_FF  prev3_pitch_rate_FS  \
# 0                  NaN                  NaN                  NaN
# 1                  0.0             1.000000             0.000000
# 2                  0.0             0.500000             0.500000
# 3                  0.0             0.666667             0.333333
# 4                  0.0             0.666667             0.333333
# 5                  0.0             1.000000             0.000000
# 6                  0.0             0.666667             0.000000
# 7                  0.0             0.666667             0.000000
# 8                  0.0             0.666667             0.000000
# 9                  0.0             0.666667             0.333333
# 10                 0.0             0.666667             0.333333
# 11                 0.0             0.666667             0.333333
# 12                 0.0             1.000000             0.000000
# 13                 0.0             1.000000             0.000000
# 14                 0.0             1.000000             0.000000
# 15                 0.0             1.000000             0.000000
# 16                 0.0             1.000000             0.000000
# 17                 0.0             0.666667             0.000000
# 18                 0.0             0.333333             0.000000
# 19                 0.0             0.333333             0.000000
#
#    prev3_pitch_rate_SL prev3_pitch_rate_ST
# 0                  NaN                 NaN
# 1             0.000000                 0.0
# 2             0.000000                 0.0
# 3             0.000000                 0.0
# 4             0.000000                 0.0
# 5             0.000000                 0.0
# 6             0.333333                 0.0
# 7             0.333333                 0.0
# 8             0.333333                 0.0
# 9             0.000000                 0.0
# 10            0.000000                 0.0
# 11            0.000000                 0.0
# 12            0.000000                 0.0
# 13            0.000000                 0.0
# 14            0.000000                 0.0
# 15            0.000000                 0.0
# 16            0.000000                 0.0
# 17            0.333333                 0.0
# 18            0.666667                 0.0
# 19            0.666667                 0.0
#
# [20 rows x 73 columns]

# %% [markdown]
# ## KG3 Model
#
# KG3 uses the same shared split and the same Random Forest preprocessing logic as KG1 and KG2.

# %%
# Prepare KG3 once for tree-based models
kg3_tree_data = prepare_model_data(kg3, train_games, model_family="tree")

print("KG3 raw train shape:", kg3_tree_data["X_train_raw"].shape)
print("KG3 processed train shape:", kg3_tree_data["X_train"].shape)
print("KG3 raw test shape:", kg3_tree_data["X_test_raw"].shape)
print("KG3 processed test shape:", kg3_tree_data["X_test"].shape)
# Out:
# KG3 raw train shape: (19949, 70)
# KG3 processed train shape: (19949, 194)
# KG3 raw test shape: (4891, 70)
# KG3 processed test shape: (4891, 194)

# %% [markdown]
# ### KG3 Random Forest

# %%
kg3_rf = RandomForestClassifier(
    n_estimators=500,
    max_depth=12,
    min_samples_leaf=5,
    min_samples_split=10,
    max_features="sqrt",
    random_state=42,
    n_jobs=-1
)

kg3_rf, kg3_rf_pred, model_results = evaluate_prepared_model(
    model=kg3_rf,
    data=kg3_tree_data,
    model_name="Random Forest",
    kg_name="KG3",
    model_family="tree",
    results_df=model_results
)
# Out:
# KG3 Random Forest Training Accuracy: 1.0000
# KG3 Random Forest Testing Accuracy : 0.5878
#
# Classification Report
#               precision    recall  f1-score   support
#
#           CH       0.00      0.00      0.00        74
#           FF       0.59      0.85      0.70      2636
#           FS       0.57      0.38      0.45      1672
#           SL       0.14      0.00      0.00       504
#           ST       0.00      0.00      0.00         5
#
#     accuracy                           0.59      4891
#    macro avg       0.26      0.25      0.23      4891
# weighted avg       0.53      0.59      0.53      4891
# KG3 Random Forest Group CV Scores: [0.58324975 0.59885029 0.61721888 0.59834628 0.59272271]
# KG3 Random Forest Mean Group CV Accuracy: 0.5981
# KG3 Random Forest Group CV Std: 0.0111
#   KG Dataset             Model Preprocessing  Train Accuracy  Test Accuracy  \
# 0        KG1  Naive Stratified          none           0.427         0.4265
# 1        KG1     Random Forest          tree           1.000         0.5915
# 2        KG2     Random Forest          tree           1.000         0.5956
# 3        KG3     Random Forest          tree           1.000         0.5878
#
#    Group CV Accuracy
# 0             0.4308
# 1             0.5984
# 2             0.6023
# 3             0.5981

# %% [markdown]
# ### KG3 Random Forest Feature Importance

# %%
kg3_rf_importance = feature_importance_table(
    model=kg3_rf,
    feature_names=kg3_tree_data["feature_names"],
    top_n=25
)

kg3_rf_importance
# Out:
#                                             Feature  Importance
# 0                  num__release_speed_of_prev_pitch    0.033869
# 1                           num__strike_zone_height    0.031501
# 2                  num__delta_run_exp_of_prev_pitch    0.031236
# 3                                       num__sz_bot    0.031080
# 4                                       num__sz_top    0.030736
# 5          num__delta_pitcher_run_exp_of_prev_pitch    0.030532
# 6                                       num__batter    0.030088
# 7                         num__pitch_number_of_game    0.030010
# 8                                  num__bat_win_exp    0.028538
# 9                   num__prior_pa_vs_pitcher_career    0.023152
# 10                       num__at_bat_number_of_game    0.022723
# 11                                     num__age_bat    0.022143
# 12  num__estimated_woba_using_speedangle_of_prev_ab    0.021631
# 13                                     num__age_pit    0.020790
# 14                          num__zone_of_prev_pitch    0.020085
# 15    num__estimated_ba_using_speedangle_of_prev_ab    0.019497
# 16                     num__hit_location_of_prev_ab    0.014644
# 17                              num__bat_score_diff    0.014246
# 18                     num__pitcher_team_score_diff    0.014127
# 19                                      num__inning    0.014021
# 20                  num__launch_speed_of_prev_pitch    0.012612
# 21                num__pitcher_days_since_prev_game    0.012317
# 22                                        num__hc_x    0.012214
# 23                             num__post_away_score    0.012184
# 24                  num__launch_angle_of_prev_pitch    0.012061

# %% [markdown]
# ## KG4 Edits
#
# KG4 uses the specified variable list from KG3. `game_pk` and `game_date` are retained only for splitting/dropping and are not included as model features.

# %%
# -------------------------
# Create kg4
# -------------------------

kg4_cols = [
    "game_date",
    "pitch_number_of_ab",
    "at_bat_number_of_game",
    "events_of_prev_ab",
    "hit_location_of_prev_ab",
    "bb_type_of_prev_ab",
    "launch_speed_angle_of_prev_ab",
    "inning",
    "n_thruorder_pitcher",
    "pitch_type",
    "batter",
    "pitcher",
    "game_type",
    "stand",
    "p_throws",
    "home_team",
    "away_team",
    "balls",
    "strikes",
    "on_3b",
    "on_2b",
    "on_1b",
    "outs_when_up",
    "inning_topbot",
    "sz_top",
    "sz_bot",
    "game_pk",
    "bat_score",
    "fld_score",
    "if_fielding_alignment",
    "of_fielding_alignment",
    "bat_win_exp",
    "age_pit",
    "age_bat",
    "n_priorpa_thisgame_player_at_bat",
    "pitcher_days_since_prev_game",
    "release_speed_of_prev_pitch",
    "description_of_prev_pitch",
    "zone_of_prev_pitch",
    "type_of_prev_pitch",
    "hit_distance_sc_of_prev_pitch",
    "launch_speed_of_prev_pitch",
    "launch_angle_of_prev_pitch",
    "pitch_type_of_prev_pitch",
    "count",
    "count_state",
    "pitch_number_of_game",
    "prior_pa_vs_pitcher_career",
    "pitcher_team_score_diff",
    "strike_zone_height",
    "prev3_pitch_rate_CH",
    "prev3_pitch_rate_FF",
    "prev3_pitch_rate_FS",
    "prev3_pitch_rate_SL",
    "prev3_pitch_rate_ST",
]

kg4 = kg3[kg4_cols].copy()

# game_pk and game_date stay in kg4 so the shared split works,
# but BASE_DROP_COLS removes them before modeling.
kg4.head()
# Out:
#     game_date  pitch_number_of_ab  at_bat_number_of_game events_of_prev_ab  \
# 0  2017-04-28                   3                      0               NaN
# 1  2017-04-28                   4                      0               NaN
# 2  2017-04-28                   5                      0               NaN
# 3  2017-04-28                   6                      0               NaN
# 4  2017-04-28                   1                      1              walk
#
#    hit_location_of_prev_ab bb_type_of_prev_ab  launch_speed_angle_of_prev_ab  \
# 0                      NaN                NaN                            NaN
# 1                      NaN                NaN                            NaN
# 2                      NaN                NaN                            NaN
# 3                      NaN                NaN                            NaN
# 4                      NaN                NaN                            NaN
#
#    inning  n_thruorder_pitcher pitch_type  ...    count_state  \
# 0       5                    2         FF  ...     even_count
# 1       5                    2         FS  ...  hitters_count
# 2       5                    2         FF  ...  hitters_count
# 3       5                    2         FF  ...     full_count
# 4       5                    2         FF  ...     even_count
#
#    pitch_number_of_game prior_pa_vs_pitcher_career pitcher_team_score_diff  \
# 0                     1                          0                       4
# 1                     2                          0                       4
# 2                     3                          0                       4
# 3                     4                          0                       4
# 4                     5                          0                       4
#
#   strike_zone_height prev3_pitch_rate_CH prev3_pitch_rate_FF  \
# 0           1.688094                 NaN                 NaN
# 1           1.736089                 0.0            1.000000
# 2           1.704043                 0.0            0.500000
# 3           1.927603                 0.0            0.666667
# 4           2.027311                 0.0            0.666667
#
#    prev3_pitch_rate_FS  prev3_pitch_rate_SL  prev3_pitch_rate_ST
# 0                  NaN                  NaN                  NaN
# 1             0.000000                  0.0                  0.0
# 2             0.500000                  0.0                  0.0
# 3             0.333333                  0.0                  0.0
# 4             0.333333                  0.0                  0.0
#
# [5 rows x 55 columns]

# %% [markdown]
# ## KG4 Model
#
# KG4 uses the same shared split and the same Random Forest preprocessing logic as KG1, KG2, and KG3.

# %%
# Prepare KG4 once for tree-based models
kg4_tree_data = prepare_model_data(kg4, train_games, model_family="tree")

print("KG4 raw train shape:", kg4_tree_data["X_train_raw"].shape)
print("KG4 processed train shape:", kg4_tree_data["X_train"].shape)
print("KG4 raw test shape:", kg4_tree_data["X_test_raw"].shape)
print("KG4 processed test shape:", kg4_tree_data["X_test"].shape)
# Out:
# KG4 raw train shape: (19949, 52)
# KG4 processed train shape: (19949, 176)
# KG4 raw test shape: (4891, 52)
# KG4 processed test shape: (4891, 176)

# %% [markdown]
# ### KG4 Random Forest

# %%
kg4_rf = RandomForestClassifier(
    n_estimators=500,
    max_depth=12,
    min_samples_leaf=5,
    min_samples_split=10,
    max_features="sqrt",
    random_state=42,
    n_jobs=-1
)

kg4_rf, kg4_rf_pred, model_results = evaluate_prepared_model(
    model=kg4_rf,
    data=kg4_tree_data,
    model_name="Random Forest",
    kg_name="KG4",
    model_family="tree",
    results_df=model_results
)
# Out:
# KG4 Random Forest Training Accuracy: 1.0000
# KG4 Random Forest Testing Accuracy : 0.5888
#
# Classification Report
#               precision    recall  f1-score   support
#
#           CH       0.00      0.00      0.00        74
#           FF       0.59      0.85      0.70      2636
#           FS       0.58      0.38      0.45      1672
#           SL       0.43      0.01      0.01       504
#           ST       0.00      0.00      0.00         5
#
#     accuracy                           0.59      4891
#    macro avg       0.32      0.25      0.23      4891
# weighted avg       0.56      0.59      0.53      4891
# KG4 Random Forest Group CV Scores: [0.58199599 0.59610097 0.60717871 0.59208218 0.58293601]
# KG4 Random Forest Mean Group CV Accuracy: 0.5921
# KG4 Random Forest Group CV Std: 0.0093
#   KG Dataset             Model Preprocessing  Train Accuracy  Test Accuracy  \
# 0        KG1  Naive Stratified          none           0.427         0.4265
# 1        KG1     Random Forest          tree           1.000         0.5915
# 2        KG2     Random Forest          tree           1.000         0.5956
# 3        KG3     Random Forest          tree           1.000         0.5878
# 4        KG4     Random Forest          tree           1.000         0.5888
#
#    Group CV Accuracy
# 0             0.4308
# 1             0.5984
# 2             0.6023
# 3             0.5981
# 4             0.5921

# %% [markdown]
# ### KG4 Random Forest Feature Importance

# %%
kg4_rf_importance = feature_importance_table(
    model=kg4_rf,
    feature_names=kg4_tree_data["feature_names"],
    top_n=25
)

kg4_rf_importance
# Out:
#                                Feature  Importance
# 0     num__release_speed_of_prev_pitch    0.041846
# 1              num__strike_zone_height    0.038776
# 2                          num__sz_bot    0.038508
# 3                          num__sz_top    0.037681
# 4            num__pitch_number_of_game    0.037470
# 5                          num__batter    0.036972
# 6                     num__bat_win_exp    0.036299
# 7           num__at_bat_number_of_game    0.028230
# 8      num__prior_pa_vs_pitcher_career    0.028198
# 9                         num__age_bat    0.027329
# 10             num__zone_of_prev_pitch    0.025570
# 11                        num__age_pit    0.024917
# 12        num__pitcher_team_score_diff    0.020006
# 13        num__hit_location_of_prev_ab    0.019551
# 14                         num__inning    0.017182
# 15                      num__fld_score    0.016046
# 16     num__launch_speed_of_prev_pitch    0.015549
# 17   num__pitcher_days_since_prev_game    0.015438
# 18  num__hit_distance_sc_of_prev_pitch    0.015051
# 19     num__launch_angle_of_prev_pitch    0.015047
# 20             num__pitch_number_of_ab    0.014814
# 21                          num__on_1b    0.014699
# 22                      num__bat_score    0.014572
# 23  num__launch_speed_angle_of_prev_ab    0.014474
# 24            num__prev3_pitch_rate_FS    0.014327

# %% [markdown]
# ## Additional Models on KG4
#
# These are the other models from the original notebook. They are kept at the end, after the KG1 → KG2 → KG3 → KG4 Random Forest workflow.
#
# Preprocessing stays consistent by model family:
# - Gradient Boosting uses the tree preprocessing prepared for KG3.
# - Logistic Regression and Linear SVM use the linear preprocessing prepared once below.
#
# To add another model later, define the model object and call `evaluate_prepared_model(...)`.

# %%
# Prepare KG3 once for linear/distance-based models
kg4_linear_data = prepare_model_data(kg4, train_games, model_family="linear")

print("KG4 linear raw train shape:", kg4_linear_data["X_train_raw"].shape)
print("KG4 linear processed train shape:", kg4_linear_data["X_train"].shape)
print("KG4 linear raw test shape:", kg4_linear_data["X_test_raw"].shape)
print("KG4 linear processed test shape:", kg4_linear_data["X_test"].shape)
# Out:
# KG4 linear raw train shape: (19949, 52)
# KG4 linear processed train shape: (19949, 176)
# KG4 linear raw test shape: (4891, 52)
# KG4 linear processed test shape: (4891, 176)

# %% [markdown]
# ### Logistic Regression

# %%
kg4_logreg = LogisticRegression(
    max_iter=2000,
    multi_class="multinomial",
    solver="lbfgs",
    random_state=42,
    n_jobs=-1
)

kg4_logreg, kg4_logreg_pred, model_results = evaluate_prepared_model(
    model=kg4_logreg,
    data=kg4_linear_data,
    model_name="Logistic Regression",
    kg_name="KG4",
    model_family="linear",
    results_df=model_results
)
# Out:
# KG4 Logistic Regression Training Accuracy: 0.5816
# KG4 Logistic Regression Testing Accuracy : 0.5663
#
# Classification Report
#               precision    recall  f1-score   support
#
#           CH       0.33      0.07      0.11        74
#           FF       0.57      0.83      0.68      2636
#           FS       0.54      0.35      0.42      1672
#           SL       0.33      0.01      0.01       504
#           ST       0.00      0.00      0.00         5
#
#     accuracy                           0.57      4891
#    macro avg       0.36      0.25      0.24      4891
# weighted avg       0.53      0.57      0.51      4891
# KG4 Logistic Regression Group CV Scores: [0.55115346 0.57735566 0.57756024 0.56928088 0.55307403]
# KG4 Logistic Regression Mean Group CV Accuracy: 0.5657
# KG4 Logistic Regression Group CV Std: 0.0115
#   KG Dataset                Model Preprocessing  Train Accuracy  \
# 0        KG1     Naive Stratified          none          0.4270
# 1        KG1        Random Forest          tree          1.0000
# 2        KG2        Random Forest          tree          1.0000
# 3        KG3        Random Forest          tree          1.0000
# 4        KG4        Random Forest          tree          1.0000
# 5        KG4  Logistic Regression        linear          0.5816
#
#    Test Accuracy  Group CV Accuracy
# 0         0.4265             0.4308
# 1         0.5915             0.5984
# 2         0.5956             0.6023
# 3         0.5878             0.5981
# 4         0.5888             0.5921
# 5         0.5663             0.5657

# %% [markdown]
# ### Gradient Boosting

# %%
kg4_gb = HistGradientBoostingClassifier(
    learning_rate=0.05,
    max_iter=300,
    max_leaf_nodes=31,
    min_samples_leaf=20,
    l2_regularization=0.1,
    random_state=42
)

kg4_gb, kg4_gb_pred, model_results = evaluate_prepared_model(
    model=kg4_gb,
    data=kg4_tree_data,
    model_name="Gradient Boosting",
    kg_name="KG4",
    model_family="tree",
    results_df=model_results
)
# Out:
# KG4 Gradient Boosting Training Accuracy: 0.6861
# KG4 Gradient Boosting Testing Accuracy : 0.5811
#
# Classification Report
#               precision    recall  f1-score   support
#
#           CH       0.00      0.00      0.00        74
#           FF       0.59      0.83      0.69      2636
#           FS       0.56      0.39      0.46      1672
#           SL       0.17      0.00      0.01       504
#           ST       0.00      0.00      0.00         5
#
#     accuracy                           0.58      4891
#    macro avg       0.26      0.24      0.23      4891
# weighted avg       0.53      0.58      0.53      4891
# KG4 Gradient Boosting Group CV Scores: [0.57547643 0.59485129 0.60918675 0.5878226  0.5761606 ]
# KG4 Gradient Boosting Mean Group CV Accuracy: 0.5887
# KG4 Gradient Boosting Group CV Std: 0.0126
#   KG Dataset                Model Preprocessing  Train Accuracy  \
# 0        KG1     Naive Stratified          none          0.4270
# 1        KG1        Random Forest          tree          1.0000
# 2        KG2        Random Forest          tree          1.0000
# 3        KG3        Random Forest          tree          1.0000
# 4        KG4        Random Forest          tree          1.0000
# 5        KG4  Logistic Regression        linear          0.5816
# 6        KG4    Gradient Boosting          tree          0.6861
#
#    Test Accuracy  Group CV Accuracy
# 0         0.4265             0.4308
# 1         0.5915             0.5984
# 2         0.5956             0.6023
# 3         0.5878             0.5981
# 4         0.5888             0.5921
# 5         0.5663             0.5657
# 6         0.5811             0.5887

# %% [markdown]
# ### KG3 Linear SVM

# %%
kg4_svm = LinearSVC(
    C=1.0,
    class_weight=None,
    max_iter=5000,
    random_state=42
)

kg4_svm, kg4_svm_pred, model_results = evaluate_prepared_model(
    model=kg4_svm,
    data=kg4_linear_data,
    model_name="Linear SVM",
    kg_name="KG4",
    model_family="linear",
    results_df=model_results
)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# KG4 Linear SVM Training Accuracy: 0.5846
# KG4 Linear SVM Testing Accuracy : 0.5686
#
# Classification Report
#               precision    recall  f1-score   support
#
#           CH       0.00      0.00      0.00        74
#           FF       0.58      0.84      0.68      2636
#           FS       0.54      0.35      0.42      1672
#           SL       0.00      0.00      0.00       504
#           ST       0.00      0.00      0.00         5
#
#     accuracy                           0.57      4891
#    macro avg       0.22      0.24      0.22      4891
# weighted avg       0.50      0.57      0.51      4891
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# KG4 Linear SVM Group CV Scores: [0.55341023 0.57810547 0.58835341 0.57729892 0.55759097]
# KG4 Linear SVM Mean Group CV Accuracy: 0.5710
# KG4 Linear SVM Group CV Std: 0.0133
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
#   KG Dataset                Model Preprocessing  Train Accuracy  \
# 0        KG1     Naive Stratified          none          0.4270
# 1        KG1        Random Forest          tree          1.0000
# 2        KG2        Random Forest          tree          1.0000
# 3        KG3        Random Forest          tree          1.0000
# 4        KG4        Random Forest          tree          1.0000
# 5        KG4  Logistic Regression        linear          0.5816
# 6        KG4    Gradient Boosting          tree          0.6861
# 7        KG4           Linear SVM        linear          0.5846
#
#    Test Accuracy  Group CV Accuracy
# 0         0.4265             0.4308
# 1         0.5915             0.5984
# 2         0.5956             0.6023
# 3         0.5878             0.5981
# 4         0.5888             0.5921
# 5         0.5663             0.5657
# 6         0.5811             0.5887
# 7         0.5686             0.5710

# %% [markdown]
# ## Final Model Comparison Table

# %%
final_model_comparison = rounded_results(model_results)
final_model_comparison
# Out:
#   KG Dataset                Model Preprocessing  Train Accuracy  \
# 0        KG1     Naive Stratified          none          0.4270
# 1        KG1        Random Forest          tree          1.0000
# 2        KG2        Random Forest          tree          1.0000
# 3        KG3        Random Forest          tree          1.0000
# 4        KG4        Random Forest          tree          1.0000
# 5        KG4  Logistic Regression        linear          0.5816
# 6        KG4    Gradient Boosting          tree          0.6861
# 7        KG4           Linear SVM        linear          0.5846
#
#    Test Accuracy  Group CV Accuracy
# 0         0.4265             0.4308
# 1         0.5915             0.5984
# 2         0.5956             0.6023
# 3         0.5878             0.5981
# 4         0.5888             0.5921
# 5         0.5663             0.5657
# 6         0.5811             0.5887
# 7         0.5686             0.5710

# %% [markdown]
# ## Results and Conclusion

# %%
#plot data
plot_df = model_results.copy()

x = np.arange(len(plot_df))
width = 0.35

plt.figure(figsize=(12, 6))

# Bars
plt.bar(x - width/2, plot_df["Train Accuracy"], width, label="Train Accuracy")
plt.bar(x + width/2, plot_df["Test Accuracy"], width, label="Test Accuracy")

# Labels
plt.xticks(
    x,
    plot_df["KG Dataset"] + " - " + plot_df["Model"],
    rotation=45,
    ha="right"
)

plt.ylabel("Accuracy")
plt.xlabel("Model")
plt.title("Training vs Testing Accuracy")
plt.ylim(0, 1)
plt.legend()

# Value labels
for i, value in enumerate(plot_df["Train Accuracy"]):
    plt.text(i - width/2, value + 0.01, f"{value:.3f}",
             ha="center", fontsize=8)

for i, value in enumerate(plot_df["Test Accuracy"]):
    plt.text(i + width/2, value + 0.01, f"{value:.3f}",
             ha="center", fontsize=8)

plt.tight_layout()
plt.show()

# %% [markdown]
# It appears that our kg2 Random Forest model is the highest performing model in testing accuracy, with a score of 59.56%, a 39.44% increase over the stratified naive baseline model. However, the kg4 Random Forest model, despite having a lower overall testing accuracy at 58.88%, performs better over Kevin Gausman's three main pitches: fastball, splitter, and slider, due to having a higher slider precision rate. When it guesses slider, it classifies correctly more than twice the rate of the kg2 model.
# The feature changes from kg2 going to kg4 are necessary, as many of the features in the kg2 dataset are very dense, and not available to the wider audience, or strategizers trying to make game-time decisions.
